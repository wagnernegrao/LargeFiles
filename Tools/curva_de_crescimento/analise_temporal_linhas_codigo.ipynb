# %%
import pandas as pd
import numpy as np

# %%
filename = '/home/wagner/Dropbox/projetos_concatenados/akka.csv'

# %%
df = pd.read_csv(filename, usecols=['Commit', 'Date', 'Project', 'blank', 'code', 'comment', 'filename', 'language'])

# %%
'''
for df in dfs:
    dfx = df.loc[df['code'] >= 13196]
    files_list = []
    unique_files = []
    
    for i in files_list:
        if(i not in unique_files):
            unique_files.append(i)
'''         

file = df.loc[df['code'] >= 13196].filename.tolist()

file[1]
# Out:
# '/home/wagnernegrao/GitHub/projetos_github/akka/akka-protobuf/src/main/java/akka/protobuf/DescriptorProtos.java'

# %%
dic = '/home/wagnernegrao/GitHub/projetos_github/akka/akka-cluster/src/main/java/akka/cluster/protobuf/msg/ClusterMessages.java'
df.loc[df['filename'] == dic].sort_values(by='Date')
# Out:
#            Commit        Date Project  blank   code  comment  \
# 1991   fd0fac263f  2013-11-11    akka    921  12975     3030
# 49012  8736fb16f9  2014-04-16    akka    921  12975     3030
# 8373   c995144e55  2014-08-25    akka    921  12975     3030
# 44751  4c7adf919f  2014-11-19    akka    921  12975     3030
# 38662  6332f888ce  2015-03-05    akka    921  12975     3030
# 15678  9fb3e147db  2016-02-02    akka    921  12979     3036
# 36231  6b32513e98  2016-04-08    akka    921  12979     3036
# 5597   3871e18acd  2016-07-15    akka    921  12979     3036
# 1      61dd7f6e35  2016-10-31    akka    924  13030     3095
# 3755   1505a54038  2017-03-09    akka    643   9092     2194
# 32644  168b40e40c  2017-06-07    akka    776  10788     2533
# 39757  511180ef39  2017-10-31    akka    825  11600     2738
# 30031  a05f50a0c0  2018-03-13    akka   1054  14135     3089
# 18724  1369d3fcdf  2018-08-24    akka   1055  14135     3092
# 41926  ca9a1710e8  2019-02-06    akka   1055  14135     3092
# 46230  55ae1ad5c4  2019-05-23    akka   1055  14135     3092
# 50596  94cc028986  2019-09-26    akka   1074  17144     3155
# 12386  aae7604dce  2020-01-14    akka   1074  17144     3790
#
#                                                 filename language
# 1991   /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 49012  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 8373   /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 44751  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 38662  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 15678  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 36231  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 5597   /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 1      /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 3755   /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 32644  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 39757  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 30031  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 18724  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 41926  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 46230  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 50596  /home/wagnernegrao/GitHub/projetos_github/akka...     Java
# 12386  /home/wagnernegrao/GitHub/projetos_github/akka...     Java

# %%
test.split('/')[len(test.split('/'))-1]
# Out:
# 'DescriptorProtos.java'
