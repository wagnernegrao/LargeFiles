# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://drive.google.com/open?id=1LC05sKlW2AIUxm-v33c_UebF9t_V14pF'
fluff, id = url.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Filename.csv')

# %%
df = pd.read_csv('Filename.csv')

df['Date'] = pd.to_datetime(df.Date) # Transforma a coluna Date para datetime
df = df.sort_values(['Date']) # Ordena a data

# %% [markdown]
# ## Texto aqui

# %%
print(f'Quantidade de tipos de arquivos removidos do dataset dataset: {len(df.Extension.unique()) - 20}')
# Out:
# Quantidade de tipos de arquivos removidos do dataset dataset: 3099

# %% [markdown]
# ### Texto aqui

# %%
dfx = df.loc[(df['Extension'] == 'c') |
              (df['Extension'] == 'cpp') |
              (df['Extension'] == 'cs') |
              (df['Extension'] == 'clj') |
              (df['Extension'] == 'coffee') |
              (df['Extension'] == 'go') |
              (df['Extension'] == 'hs') |
              (df['Extension'] == 'java') |
              (df['Extension'] == 'js') |
              (df['Extension'] == 'kt') |
              (df['Extension'] == 'lua') |
              (df['Extension'] == 'm') |
              (df['Extension'] == 'php') |
              (df['Extension'] == 'py') |
              (df['Extension'] == 'rb') |
              (df['Extension'] == 'rs') |
              (df['Extension'] == 'scala') |
              (df['Extension'] == 'swift') |
              (df['Extension'] == 'ts') |
              (df['Extension'] == 'exs')
             ]

# %%
len(dfx.Project_Name.unique())
# Out:
# 212

# %% [markdown]
# ### Texto aqui

# %%
print(f'Media de LOC: {dfx.linesOfCode.mean()}')
print(f'Mediana de LOC: {dfx.linesOfCode.median()}')
print(f'Percentil de 95%: {dfx.linesOfCode.quantile(0.95)}')
print(f'Percentil de 99%: {dfx.linesOfCode.quantile(0.99)}')
# Out:
# Media de LOC: 1826.7619615525734
# Mediana de LOC: 1075.0
# Percentil de 95%: 5560.0
# Percentil de 99%: 13196.0

# %% [markdown]
# ## testo aqui

# %%
value_quantil = dfx.linesOfCode.quantile(0.99)
dfx1 = dfx.loc[dfx['linesOfCode'] >= value_quantil]


print(f'Quantidade de arquivos de codigo fonte: {len(dfx1.Extension)}')
print(f'Quantidade de projetos: {len(dfx1.Project_Name.unique())}')
# Out:
# Quantidade de arquivos de codigo fonte: 16677
# Quantidade de projetos: 79
